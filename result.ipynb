# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
for path, dirs, files in os.walk("./Results/show"):
    for file in files:
        print(os.path.join(path, file))
        Y_pred = pd.read_csv(os.path.join(path, file))
        plt.plot(Y_pred['Steam_flow'], label=file)
plt.legend()
# Out:
# ./Results/show/result_11062_171.csv
# ./Results/show/result_11033_171.csv
# ./Results/show/result_11094_097.csv

# %%
from sklearn.metrics import mean_squared_error
aa = pd.read_csv("Results/show/result_10301_203.csv")
bb = pd.read_csv("Results/show/result_10303_212.csv")

print('val_error', mean_squared_error(aa['Steam_flow'], bb['Steam_flow'], squared=False))
# aa['Steam_flow'] = (aa['Steam_flow'] + bb['Steam_flow'])/2
# aa.to_csv("Results/show/result_.csv", index=False, sep=',')
# Out:
# val_error 0.722999759697616

# %%
plt.plot(aa['Steam_flow'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /mnt/DATA1/wuliubin/Download/steam/lightgbm/result.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B10.24.99.189/mnt/DATA1/wuliubin/Download/steam/lightgbm/result.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> plt.plot(aa['Steam_flow'])
#
# NameError: name 'aa' is not defined

# %%
aa['Steam_flow']
# Out:
# 0       57.610632
# 1       57.610632
# 2       57.610632
# 3       57.598701
# 4       57.598701
#           ...
# 1795    57.362120
# 1796    57.315500
# 1797    57.315500
# 1798    57.407053
# 1799    57.657739
# Name: Steam_flow, Length: 1800, dtype: float64

# %%
###  模块与数据导入

# 模块导入
import os 
import math

import scipy
import numpy as np
import pandas as pd
import seaborn as sns
import missingno as msno
import lightgbm as lgb
import xgboost as xgb
import featuretools as ft
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures

import utils

# 数据导入
combi = pd.read_csv('Dataset/combi.csv')

# 划分训练集，验证集，测试集
train_data = combi[combi['Time'] < '2021-12-22 08:00:00']
val_data = combi[(combi['Time'] > '2021-12-22 08:00:00') & (combi['Time'] < '2021-12-22 23:30:00')]
pred_data = combi[combi['Time'] >= '2021-12-22 23:30:00']
Train_data = pd.concat([train_data, val_data], axis=0)

plt.figure(figsize=(16, 6))
# plt.plot(train_data['Steam_flow'])
plt.plot(val_data['Steam_flow'])
plt.plot(np.linspace(257384, 259183, 1800), aa['Steam_flow'])
